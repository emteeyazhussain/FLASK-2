# %%
# Q1.
# Flask is a lightweight and flexible Python web framework that allows developers to easily create web applications. It is
# designed to be simple and easy to use, yet powerful enough to handle complex web applications. Flask follows the
# Model-View-Controller (MVC) pattern, which separates the business logic (model), presentation layer (view), and 
# user interaction (controller) into separate components.

# Advantages of Flask Framework include:

# Lightweight and flexible: Flask is a lightweight framework that doesn't come with a lot of overhead. This makes it easy to
# use and flexible enough to be customized to fit specific needs.

# Easy to learn and use: Flask has a simple and intuitive API that makes it easy to learn and use. It doesn't require
# extensive configuration or boilerplate code, which makes it quick to get started with.

# Highly extensible: Flask is highly extensible and provides a wide range of extensions that can be used to add extra 
# functionality to your web application, such as database integration, user authentication, and caching.

# Built-in development server: Flask comes with a built-in development server, which makes it easy to test and debug your
# application during development.

# Large and supportive community: Flask has a large and supportive community of developers who have created a wide range of 
# extensions, tutorials, and resources that can be used to help you develop your application.

# Scalable: Flask is designed to be scalable and can be used to develop small, simple applications or large, complex web 
# applications.

# %%
# Q2
# from flask import Flask

# app = Flask(__name__)

# @app.route("/")
# def hello_world():
#     return "Hello World!!"

# if __name__=="__main__":
#     app.run(host="0.0.0.0")

# %% [markdown]
# ![hello.jpeg](attachment:c750eb55-3807-41a5-98ca-b66804222b0d.jpeg)

# %%
#Q3 
#In Flask, app routing refers to the process of mapping URLs to functions in your application. It is a way to define the 
# different endpoints (or routes) of your web application and to specify what code should be executed when a user visits each
# endpoint.

# App routes are used in Flask to define the different URLs that your application can respond to. When a user navigates to a 
# specific URL in your application, Flask uses the app routes that you have defined to determine which function should be 
# called to handle the request.

# %%
#Q4.
# from flask import Flask

# app = Flask(__name__)


# @app.route("/welcome")
# def company():
#    return "<h2>Welcome to ABC Corporation</h2>"


# @app.route("/")
# def company_details():
#   Company_Name = "ABC Corporation"
#   Location =  "India"
#   Contact_Detail =  "999-999-9999"

#   return f"the name of the comany is {Company_Name} and the location is { Location} and contact detail is {Contact_Detail}"


# if __name__=="__main__":
#     app.run(host="0.0.0.0")

# %% [markdown]
# ![screenshot.jpeg](attachment:6b2e8088-2970-4009-83ce-85b8af10a318.jpeg)

# %%
# Q5.In Flask, the url_for() function is used for URL building. The url_for() function generates a URL for the specified 
# endpoint (function) of your Flask application, based on the endpoint name and any arguments that are passed to the function.

# %% [markdown]
# ![Screenshot (10).png](attachment:0d71e644-321b-4e87-bb43-5699d0965533.png)

# %% [markdown]
# #Q6.
#
#
# # POSTMAN TO TEST IT
#
#
#
#
#
#
#
#
#
#
#
# [Capture1.PNG](attachment:ea41f2ea-f8a2-4468-aaf1-c5fff8cfa874.PNG)
